# %%
pip install sklearn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting sklearn
#   Downloading sklearn-0.0.post7.tar.gz (3.6 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: sklearn
#   Building wheel for sklearn (setup.py) ... done
#   Created wheel for sklearn: filename=sklearn-0.0.post7-py3-none-any.whl size=2953 sha256=e5a26a6b09369d0e64badf3a161458c5bc26f40ea46d9015cdaa0a7124e8a3d7
#   Stored in directory: /home/u115973/.cache/pip/wheels/c8/9c/85/72901eb50bc4bc6e3b2629378d172384ea3dfd19759c77fd2c
# Successfully built sklearn
# Installing collected packages: sklearn
# Successfully installed sklearn-0.0.post7
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tensorflow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting tensorflow
#   Downloading tensorflow-2.13.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (524.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 524.1/524.1 MB 4.5 MB/s eta 0:00:0000:0100:01
# Collecting opt-einsum>=2.3.2
#   Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 3.3 MB/s eta 0:00:00
# Collecting typing-extensions<4.6.0,>=3.6.6
#   Downloading typing_extensions-4.5.0-py3-none-any.whl (27 kB)
# Collecting tensorflow-estimator<2.14,>=2.13.0
#   Downloading tensorflow_estimator-2.13.0-py2.py3-none-any.whl (440 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 440.8/440.8 kB 15.0 MB/s eta 0:00:00
# Collecting wrapt>=1.11.0
#   Downloading wrapt-1.15.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.4/78.4 kB 4.4 MB/s eta 0:00:00
# Collecting termcolor>=1.1.0
#   Downloading termcolor-2.3.0-py3-none-any.whl (6.9 kB)
# Requirement already satisfied: packaging in /home/common/miniconda3/envs/pytorch_cpu/lib/python3.10/site-packages (from tensorflow) (23.1)
# Collecting gast<=0.4.0,>=0.2.1
#   Downloading gast-0.4.0-py3-none-any.whl (9.8 kB)
# Requirement already satisfied: six>=1.12.0 in /home/common/miniconda3/envs/pytorch_cpu/lib/python3.10/site-packages (from tensorflow) (1.16.0)
# Collecting keras<2.14,>=2.13.1
#   Downloading keras-2.13.1-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 8.8 MB/s eta 0:00:00:00:010:01m
# Collecting google-pasta>=0.1.1
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 5.0 MB/s eta 0:00:00
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3
#   Downloading protobuf-4.23.4-cp37-abi3-manylinux2014_x86_64.whl (304 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 304.5/304.5 kB 12.0 MB/s eta 0:00:00
# Collecting absl-py>=1.0.0
#   Downloading absl_py-1.4.0-py3-none-any.whl (126 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.5/126.5 kB 6.3 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in /home/common/miniconda3/envs/pytorch_cpu/lib/python3.10/site-packages (from tensorflow) (67.8.0)
# Collecting h5py>=2.9.0
#   Downloading h5py-3.9.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 30.4 MB/s eta 0:00:0000:0100:01
# Collecting tensorboard<2.14,>=2.13
#   Downloading tensorboard-2.13.0-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 32.1 MB/s eta 0:00:0000:0100:01
# Collecting astunparse>=1.6.0
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1
#   Downloading tensorflow_io_gcs_filesystem-0.33.0-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (2.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 28.4 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: numpy<=1.24.3,>=1.22 in /home/common/miniconda3/envs/pytorch_cpu/lib/python3.10/site-packages (from tensorflow) (1.24.3)
# Collecting libclang>=13.0.0
#   Downloading libclang-16.0.6-py2.py3-none-manylinux2010_x86_64.whl (22.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.9/22.9 MB 25.4 MB/s eta 0:00:0000:0100:01
# Collecting grpcio<2.0,>=1.24.3
#   Downloading grpcio-1.56.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 31.7 MB/s eta 0:00:0000:0100:01
# Collecting flatbuffers>=23.1.21
#   Downloading flatbuffers-23.5.26-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/common/miniconda3/envs/pytorch_cpu/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow) (0.38.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/common/miniconda3/envs/pytorch_cpu/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow) (2.31.0)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0
#   Downloading tensorboard_data_server-0.7.1-py3-none-manylinux2014_x86_64.whl (6.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 33.9 MB/s eta 0:00:0000:0100:01
# Collecting google-auth-oauthlib<1.1,>=0.5
#   Downloading google_auth_oauthlib-1.0.0-py2.py3-none-any.whl (18 kB)
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.4.4-py3-none-any.whl (94 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.2/94.2 kB 6.3 MB/s eta 0:00:00
# Collecting werkzeug>=1.0.1
#   Downloading Werkzeug-2.3.6-py3-none-any.whl (242 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.5/242.5 kB 11.0 MB/s eta 0:00:00
# Collecting google-auth<3,>=1.6.3
#   Downloading google_auth-2.22.0-py2.py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.8/181.8 kB 10.3 MB/s eta 0:00:00
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.3.0-py2.py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.3/181.3 kB 10.4 MB/s eta 0:00:00
# Collecting cachetools<6.0,>=2.0.0
#   Downloading cachetools-5.3.1-py3-none-any.whl (9.3 kB)
# Collecting urllib3<2.0
#   Downloading urllib3-1.26.16-py2.py3-none-any.whl (143 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.1/143.1 kB 7.4 MB/s eta 0:00:00
# Collecting requests-oauthlib>=0.7.0
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /home/common/miniconda3/envs/pytorch_cpu/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow) (2023.5.7)
# Requirement already satisfied: idna<4,>=2.5 in /home/common/miniconda3/envs/pytorch_cpu/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/common/miniconda3/envs/pytorch_cpu/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow) (3.1.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/common/miniconda3/envs/pytorch_cpu/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.14,>=2.13->tensorflow) (2.1.3)
# Collecting pyasn1<0.6.0,>=0.4.6
#   Downloading pyasn1-0.5.0-py2.py3-none-any.whl (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.9/83.9 kB 6.2 MB/s eta 0:00:00
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.7/151.7 kB 10.2 MB/s eta 0:00:00
# Installing collected packages: libclang, flatbuffers, wrapt, werkzeug, urllib3, typing-extensions, termcolor, tensorflow-io-gcs-filesystem, tensorflow-estimator, tensorboard-data-server, pyasn1, protobuf, opt-einsum, oauthlib, markdown, keras, h5py, grpcio, google-pasta, gast, cachetools, astunparse, absl-py, rsa, pyasn1-modules, requests-oauthlib, google-auth, google-auth-oauthlib, tensorboard, tensorflow
#   WARNING: The script markdown_py is installed in '/home/u115973/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts pyrsa-decrypt, pyrsa-encrypt, pyrsa-keygen, pyrsa-priv2pub, pyrsa-sign and pyrsa-verify are installed in '/home/u115973/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
# !pip install gTTS
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting gTTS
#   Downloading gTTS-2.3.2-py3-none-any.whl (28 kB)
# Collecting click<8.2,>=7.1
#   Downloading click-8.1.6-py3-none-any.whl (97 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.9/97.9 kB 5.2 MB/s eta 0:00:00
# Requirement already satisfied: requests<3,>=2.27 in /home/common/miniconda3/envs/pytorch_xpu/lib/python3.10/site-packages (from gTTS) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/common/miniconda3/envs/pytorch_xpu/lib/python3.10/site-packages (from requests<3,>=2.27->gTTS) (3.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/common/miniconda3/envs/pytorch_xpu/lib/python3.10/site-packages (from requests<3,>=2.27->gTTS) (2023.5.7)
# Requirement already satisfied: idna<4,>=2.5 in /home/common/miniconda3/envs/pytorch_xpu/lib/python3.10/site-packages (from requests<3,>=2.27->gTTS) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.local/lib/python3.10/site-packages (from requests<3,>=2.27->gTTS) (1.26.16)
# Installing collected packages: click, gTTS
# Successfully installed click-8.1.6 gTTS-2.3.2

# %%
from gtts import gTTS
from sklearn.preprocessing import StandardScaler

# Assuming 'X' is your feature matrix
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)


# Text to be converted to speech
text = "Step by Step Guidelines for setting up the  IDC and to launch the Jupyter Notebook.  Generate an ssh key using the command ssh-keygen in the power shell as an administrator. 2. Open the generated key file using notepad and copy the contents of the  file.is the path file name is id_rsa.pub Nextly login or register into the Developer Cloud and add the key under the profile section. Open .ssh folder and create a config file with the below commands: On Powershell type ssh myidc to connect to your head node instance. This will enable you  to be authenticated.   Configure your shell using the command conda init bash  Close the existing instance to make sure that the configuration changes reflect using the  command exit You are taken back to the head node again, connect to the interactive node again by  repeating Step6 again.  To check the available environments type in the command conda env list 11. Choose the environment of your choice by typing in conda activate env_name."

# Create a gTTS object
tts = gTTS(text, lang='en')

# Save the audio file
audio_file = 'output.mp3'
tts.save(audio_file)

# Play the audio directly in Colab
audio_clip = Audio(audio_file)
display(audio_clip)


print("Text-to-speech conversion completed.")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# Text-to-speech conversion completed.

# %%
pip install PyAudio
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting PyAudio
#   Using cached PyAudio-0.2.13.tar.gz (46 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Building wheels for collected packages: PyAudio
#   Building wheel for PyAudio (pyproject.toml) ... error
#   error: subprocess-exited-with-error
#
#   × Building wheel for PyAudio (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [18 lines of output]
#       running bdist_wheel
#       running build
#       running build_py
#       creating build
#       creating build/lib.linux-x86_64-cpython-310
#       creating build/lib.linux-x86_64-cpython-310/pyaudio
#       copying src/pyaudio/__init__.py -> build/lib.linux-x86_64-cpython-310/pyaudio
#       running build_ext
#       building 'pyaudio._portaudio' extension
#       creating build/temp.linux-x86_64-cpython-310
#       creating build/temp.linux-x86_64-cpython-310/src
#       creating build/temp.linux-x86_64-cpython-310/src/pyaudio
#       gcc -pthread -B /home/common/miniconda3/envs/pytorch_xpu/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /home/common/miniconda3/envs/pytorch_xpu/include -fPIC -O2 -isystem /home/common/miniconda3/envs/pytorch_xpu/include -fPIC -I/usr/local/include -I/usr/include -I/home/common/miniconda3/envs/pytorch_xpu/include/python3.10 -c src/pyaudio/device_api.c -o build/temp.linux-x86_64-cpython-310/src/pyaudio/device_api.o
#       src/pyaudio/device_api.c:9:10: fatal error: portaudio.h: No such file or directory
#           9 | #include "portaudio.h"
#             |          ^~~~~~~~~~~~~
#       compilation terminated.
#       error: command '/usr/bin/gcc' failed with exit code 1
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for PyAudio
# Failed to build PyAudio
# ERROR: Could not build wheels for PyAudio, which is required to install pyproject.toml-based projects
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy in /home/common/miniconda3/envs/pytorch_xpu/lib/python3.10/site-packages (1.24.3)

# %%
# !pip install pyttsx3
# !pip install comtypes
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pyttsx3 in ./.local/lib/python3.10/site-packages (2.90)
# Defaulting to user installation because normal site-packages is not writeable
# Collecting comtypes
#   Downloading comtypes-1.2.0-py2.py3-none-any.whl (184 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 kB 9.6 MB/s eta 0:00:00
# Installing collected packages: comtypes
# Successfully installed comtypes-1.2.0

# %%
import pyttsx3

# Function to convert text to speech
def text_to_speech(text):
    engine = pyttsx3.init(driverName='sapi5')
    engine.say(text)
    engine.runAndWait()

# Function to read text from a file
def read_text_from_file(file_path):
    with open(file_path, 'r') as file:
        text = file.read()
    return text

# Main program
if __name__ == "__main__":
    file_path = "Sample.txt"  # Replace with the path to your file
    text = read_text_from_file(file_path)
    
    if text:
        text_to_speech(text)
        print("Text converted to speech successfully!")
    else:
        print("No text found in the file.")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/pyttsx3/__init__.py:20, in init(driverName, debug)
#      19 try:
# ---> 20     eng = _activeEngines[driverName]
#      21 except KeyError:
#
# File /home/common/miniconda3/envs/pytorch_xpu/lib/python3.10/weakref.py:137, in WeakValueDictionary.__getitem__(self, key)
#     136     self._commit_removals()
# --> 137 o = self.data[key]()
#     138 if o is None:
#
# KeyError: 'sapi5'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[10], line 21
#      18 text = read_text_from_file(file_path)
#      20 if text:
# ---> 21     text_to_speech(text)
#      22     print("Text converted to speech successfully!")
#      23 else:
#
# Cell In[10], line 5, in text_to_speech(text)
#       4 def text_to_speech(text):
# ----> 5     engine = pyttsx3.init(driverName='sapi5')
#       6     engine.say(text)
#       7     engine.runAndWait()
#
# File ~/.local/lib/python3.10/site-packages/pyttsx3/__init__.py:22, in init(driverName, debug)
#      20     eng = _activeEngines[driverName]
#      21 except KeyError:
# ---> 22     eng = Engine(driverName, debug)
#      23     _activeEngines[driverName] = eng
#      24 return eng
#
# File ~/.local/lib/python3.10/site-packages/pyttsx3/engine.py:30, in Engine.__init__(self, driverName, debug)
#      20 def __init__(self, driverName=None, debug=False):
#      21     """
#      22     Constructs a new TTS engine instance.
#      23
#    (...)
#      28     @type debug: bool
#      29     """
# ---> 30     self.proxy = driver.DriverProxy(weakref.proxy(self), driverName, debug)
#      31     # initialize other vars
#      32     self._connects = {}
#
# File ~/.local/lib/python3.10/site-packages/pyttsx3/driver.py:50, in DriverProxy.__init__(self, engine, driverName, debug)
#      48 # import driver module
#      49 name = 'pyttsx3.drivers.%s' % driverName
# ---> 50 self._module = importlib.import_module(name)
#      51 # build driver instance
#      52 self._driver = self._module.buildDriver(weakref.proxy(self))
#
# File /home/common/miniconda3/envs/pytorch_xpu/lib/python3.10/importlib/__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1050, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1006, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:688, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:883, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~/.local/lib/python3.10/site-packages/pyttsx3/drivers/sapi5.py:1
# ----> 1 import comtypes.client  # Importing comtypes.client will make the gen subpackage
#       2 try:
#       3     from comtypes.gen import SpeechLib  # comtypes
#
# File ~/.local/lib/python3.10/site-packages/comtypes/__init__.py:7
#       5 from ctypes import *
#       6 from ctypes import _SimpleCData
# ----> 7 from _ctypes import COMError
#       8 import logging
#       9 import os
#
# ImportError: cannot import name 'COMError' from '_ctypes' (/home/common/miniconda3/envs/pytorch_xpu/lib/python3.10/lib-dynload/_ctypes.cpython-310-x86_64-linux-gnu.so)

# %%
# !pip install scikit-learn-intelex
from sklearnex import patch_sklearn
patch_sklearn()
# !pip install sklearn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-learn-intelex in ./.local/lib/python3.10/site-packages (2023.2.1)
# Requirement already satisfied: daal4py==2023.2.1 in ./.local/lib/python3.10/site-packages (from scikit-learn-intelex) (2023.2.1)
# Requirement already satisfied: scikit-learn>=0.22 in ./.local/lib/python3.10/site-packages (from scikit-learn-intelex) (1.3.0)
# Requirement already satisfied: numpy>=1.19 in /home/common/miniconda3/envs/pytorch_xpu/lib/python3.10/site-packages (from daal4py==2023.2.1->scikit-learn-intelex) (1.24.3)
# Requirement already satisfied: daal==2023.2.1 in ./.local/lib/python3.10/site-packages (from daal4py==2023.2.1->scikit-learn-intelex) (2023.2.1)
# Requirement already satisfied: tbb==2021.* in ./.local/lib/python3.10/site-packages (from daal==2023.2.1->daal4py==2023.2.1->scikit-learn-intelex) (2021.10.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in ./.local/lib/python3.10/site-packages (from scikit-learn>=0.22->scikit-learn-intelex) (3.2.0)
# Requirement already satisfied: joblib>=1.1.1 in ./.local/lib/python3.10/site-packages (from scikit-learn>=0.22->scikit-learn-intelex) (1.3.2)
# Requirement already satisfied: scipy>=1.5.0 in ./.local/lib/python3.10/site-packages (from scikit-learn>=0.22->scikit-learn-intelex) (1.11.1)
# Intel(R) Extension for Scikit-learn* enabled (https://github.com/intel/scikit-learn-intelex)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: sklearn in ./.local/lib/python3.10/site-packages (0.0.post7)

# %%
from sklearn.preprocessing import StandardScaler
from sklearnex import patch_sklearn
patch_sklearn()
import tensorflow as tf
# Out:
# Intel(R) Extension for Scikit-learn* enabled (https://github.com/intel/scikit-learn-intelex)
